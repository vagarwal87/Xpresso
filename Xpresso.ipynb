# %% [markdown]
# <div>
#   <center>
#   <img src="https://drive.google.com/uc?id=1IHXf1W23kjHNsPR4pt61pWa0-43R7BL1" width="400"/>
#   </center>
# </div>
#
# **Agarwal V, Shendure J**. [Predicting mRNA abundance directly from genomic sequence using deep convolutional neural networks](https://doi.org/10.1101/416685). 2020. *Cell Reports*. [*Github*](https://github.com/vagarwal87/Xpresso). [*Website*](https://xpresso.gs.washington.edu).

# %% [markdown]
# # Setup Xpresso dependencies, datasets, and imports

# %%
#Run with Python3/GPU-enabled runtime

#Train/Valid/Test set for predicting median gene expression levels in the human
# !wget -r -np -nH --reject "index.html*" --cut-dirs 6 \
 https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/
#Train/Valid/Test set for predicting median gene expression levels in the mouse
# !wget -r -np -nH --reject "index.html*" --cut-dirs 6 \
 https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/
#Prepare set of input sequences to generate predictions
# !wget https://xpresso.gs.washington.edu/data/Xpresso-predict.zip
# !unzip Xpresso-predict.zip

#set up dependencies
# !pip install biopython
# !pip install hyperopt
# %tensorflow_version 1.x

#set up imports
import tensorflow as tf
import sys, gzip, h5py, pickle, os
import numpy as np
import pandas as pd
from mimetypes import guess_type
from Bio import SeqIO
from functools import partial
from scipy import stats
from IPython.display import Image

from tensorflow import keras
from keras.models import Model, load_model
from keras.utils.vis_utils import plot_model
from keras.optimizers import Adam, SGD
from keras.layers import *
from keras.metrics import *
from keras.callbacks import Callback, ModelCheckpoint, EarlyStopping
from hyperopt import hp, STATUS_OK

print("TF version", tf.__version__)
print("Keras version", keras.__version__)
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# --2020-03-20 17:08:14--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/
# Resolving krishna.gs.washington.edu (krishna.gs.washington.edu)... 128.208.8.159
# Connecting to krishna.gs.washington.edu (krishna.gs.washington.edu)|128.208.8.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:14 (359 MB/s) - ‘pM10Kb_1KTest/index.html.tmp’ saved [1403/1403]
#
# Loading robots.txt; please ignore errors.
# --2020-03-20 17:08:14--  https://krishna.gs.washington.edu/robots.txt
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-03-20 17:08:14 ERROR 404: Not Found.
#
# Removing pM10Kb_1KTest/index.html.tmp since it should be rejected.
#
# --2020-03-20 17:08:14--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/?C=N;O=D
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html?C=N;O=D.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:14 (463 MB/s) - ‘pM10Kb_1KTest/index.html?C=N;O=D.tmp’ saved [1403/1403]
#
# Removing pM10Kb_1KTest/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2020-03-20 17:08:14--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/?C=M;O=A
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html?C=M;O=A.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:14 (492 MB/s) - ‘pM10Kb_1KTest/index.html?C=M;O=A.tmp’ saved [1403/1403]
#
# Removing pM10Kb_1KTest/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2020-03-20 17:08:14--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/?C=S;O=A
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html?C=S;O=A.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:14 (505 MB/s) - ‘pM10Kb_1KTest/index.html?C=S;O=A.tmp’ saved [1403/1403]
#
# Removing pM10Kb_1KTest/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2020-03-20 17:08:14--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/?C=D;O=A
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html?C=D;O=A.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:14 (478 MB/s) - ‘pM10Kb_1KTest/index.html?C=D;O=A.tmp’ saved [1403/1403]
#
# Removing pM10Kb_1KTest/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2020-03-20 17:08:14--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/test.h5
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16136880 (15M)
# Saving to: ‘pM10Kb_1KTest/test.h5’
#
# pM10Kb_1KTest/test. 100%[===================>]  15.39M  9.83MB/s    in 1.6s
#
# 2020-03-20 17:08:16 (9.83 MB/s) - ‘pM10Kb_1KTest/test.h5’ saved [16136880/16136880]
#
# --2020-03-20 17:08:16--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/train.h5
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 263128854 (251M)
# Saving to: ‘pM10Kb_1KTest/train.h5’
#
# pM10Kb_1KTest/train 100%[===================>] 250.94M  34.7MB/s    in 7.1s
#
# 2020-03-20 17:08:23 (35.4 MB/s) - ‘pM10Kb_1KTest/train.h5’ saved [263128854/263128854]
#
# --2020-03-20 17:08:23--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/valid.h5
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16127898 (15M)
# Saving to: ‘pM10Kb_1KTest/valid.h5’
#
# pM10Kb_1KTest/valid 100%[===================>]  15.38M  40.7MB/s    in 0.4s
#
# 2020-03-20 17:08:24 (40.7 MB/s) - ‘pM10Kb_1KTest/valid.h5’ saved [16127898/16127898]
#
# --2020-03-20 17:08:24--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/?C=N;O=A
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html?C=N;O=A.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:24 (520 MB/s) - ‘pM10Kb_1KTest/index.html?C=N;O=A.tmp’ saved [1403/1403]
#
# Removing pM10Kb_1KTest/index.html?C=N;O=A.tmp since it should be rejected.
#
# --2020-03-20 17:08:24--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/?C=M;O=D
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html?C=M;O=D.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:24 (518 MB/s) - ‘pM10Kb_1KTest/index.html?C=M;O=D.tmp’ saved [1403/1403]
#
# Removing pM10Kb_1KTest/index.html?C=M;O=D.tmp since it should be rejected.
#
# --2020-03-20 17:08:24--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/?C=S;O=D
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html?C=S;O=D.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:24 (543 MB/s) - ‘pM10Kb_1KTest/index.html?C=S;O=D.tmp’ saved [1403/1403]
#
# Removing pM10Kb_1KTest/index.html?C=S;O=D.tmp since it should be rejected.
#
# --2020-03-20 17:08:24--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest/?C=D;O=D
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1403 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest/index.html?C=D;O=D.tmp’
#
# pM10Kb_1KTest/index 100%[===================>]   1.37K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:24 (586 MB/s) - ‘pM10Kb_1KTest/index.html?C=D;O=D.tmp’ saved [1403/1403]
#
# Removing pM10Kb_1KTest/index.html?C=D;O=D.tmp since it should be rejected.
#
# FINISHED --2020-03-20 17:08:24--
# Total wall clock time: 10s
# Downloaded: 12 files, 282M in 9.0s (31.2 MB/s)
# --2020-03-20 17:08:25--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/
# Resolving krishna.gs.washington.edu (krishna.gs.washington.edu)... 128.208.8.159
# Connecting to krishna.gs.washington.edu (krishna.gs.washington.edu)|128.208.8.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:25 (428 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html.tmp’ saved [1415/1415]
#
# Loading robots.txt; please ignore errors.
# --2020-03-20 17:08:25--  https://krishna.gs.washington.edu/robots.txt
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 404 Not Found
# 2020-03-20 17:08:25 ERROR 404: Not Found.
#
# Removing pM10Kb_1KTest_Mouse/index.html.tmp since it should be rejected.
#
# --2020-03-20 17:08:25--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/?C=N;O=D
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html?C=N;O=D.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:25 (350 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html?C=N;O=D.tmp’ saved [1415/1415]
#
# Removing pM10Kb_1KTest_Mouse/index.html?C=N;O=D.tmp since it should be rejected.
#
# --2020-03-20 17:08:25--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/?C=M;O=A
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html?C=M;O=A.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:25 (463 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html?C=M;O=A.tmp’ saved [1415/1415]
#
# Removing pM10Kb_1KTest_Mouse/index.html?C=M;O=A.tmp since it should be rejected.
#
# --2020-03-20 17:08:25--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/?C=S;O=A
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html?C=S;O=A.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:25 (496 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html?C=S;O=A.tmp’ saved [1415/1415]
#
# Removing pM10Kb_1KTest_Mouse/index.html?C=S;O=A.tmp since it should be rejected.
#
# --2020-03-20 17:08:25--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/?C=D;O=A
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html?C=D;O=A.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:25 (506 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html?C=D;O=A.tmp’ saved [1415/1415]
#
# Removing pM10Kb_1KTest_Mouse/index.html?C=D;O=A.tmp since it should be rejected.
#
# --2020-03-20 17:08:25--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/test.h5
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16101376 (15M)
# Saving to: ‘pM10Kb_1KTest_Mouse/test.h5’
#
# pM10Kb_1KTest_Mouse 100%[===================>]  15.36M  9.92MB/s    in 1.5s
#
# 2020-03-20 17:08:27 (9.92 MB/s) - ‘pM10Kb_1KTest_Mouse/test.h5’ saved [16101376/16101376]
#
# --2020-03-20 17:08:27--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/train.h5
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 318166951 (303M)
# Saving to: ‘pM10Kb_1KTest_Mouse/train.h5’
#
# pM10Kb_1KTest_Mouse 100%[===================>] 303.43M  36.3MB/s    in 8.6s
#
# 2020-03-20 17:08:36 (35.4 MB/s) - ‘pM10Kb_1KTest_Mouse/train.h5’ saved [318166951/318166951]
#
# --2020-03-20 17:08:36--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/valid.h5
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 16098395 (15M)
# Saving to: ‘pM10Kb_1KTest_Mouse/valid.h5’
#
# pM10Kb_1KTest_Mouse 100%[===================>]  15.35M  37.9MB/s    in 0.4s
#
# 2020-03-20 17:08:36 (37.9 MB/s) - ‘pM10Kb_1KTest_Mouse/valid.h5’ saved [16098395/16098395]
#
# --2020-03-20 17:08:36--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/?C=N;O=A
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html?C=N;O=A.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:36 (305 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html?C=N;O=A.tmp’ saved [1415/1415]
#
# Removing pM10Kb_1KTest_Mouse/index.html?C=N;O=A.tmp since it should be rejected.
#
# --2020-03-20 17:08:36--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/?C=M;O=D
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html?C=M;O=D.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:36 (533 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html?C=M;O=D.tmp’ saved [1415/1415]
#
# Removing pM10Kb_1KTest_Mouse/index.html?C=M;O=D.tmp since it should be rejected.
#
# --2020-03-20 17:08:36--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/?C=S;O=D
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html?C=S;O=D.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:36 (566 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html?C=S;O=D.tmp’ saved [1415/1415]
#
# Removing pM10Kb_1KTest_Mouse/index.html?C=S;O=D.tmp since it should be rejected.
#
# --2020-03-20 17:08:36--  https://krishna.gs.washington.edu/content/members/vagar/Xpresso/data/datasets/pM10Kb_1KTest_Mouse/?C=D;O=D
# Reusing existing connection to krishna.gs.washington.edu:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1415 (1.4K) [text/html]
# Saving to: ‘pM10Kb_1KTest_Mouse/index.html?C=D;O=D.tmp’
#
# pM10Kb_1KTest_Mouse 100%[===================>]   1.38K  --.-KB/s    in 0s
#
# 2020-03-20 17:08:37 (551 MB/s) - ‘pM10Kb_1KTest_Mouse/index.html?C=D;O=D.tmp’ saved [1415/1415]
#
# Removing pM10Kb_1KTest_Mouse/index.html?C=D;O=D.tmp since it should be rejected.
#
# FINISHED --2020-03-20 17:08:37--
# Total wall clock time: 12s
# Downloaded: 12 files, 334M in 11s (31.7 MB/s)
# --2020-03-20 17:08:37--  https://xpresso.gs.washington.edu/data/Xpresso-predict.zip
# Resolving xpresso.gs.washington.edu (xpresso.gs.washington.edu)... 128.208.8.159
# Connecting to xpresso.gs.washington.edu (xpresso.gs.washington.edu)|128.208.8.159|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 129181083 (123M) [application/zip]
# Saving to: ‘Xpresso-predict.zip’
#
# Xpresso-predict.zip 100%[===================>] 123.20M  36.5MB/s    in 4.5s
#
# 2020-03-20 17:08:42 (27.4 MB/s) - ‘Xpresso-predict.zip’ saved [129181083/129181083]
#
# Archive:  Xpresso-predict.zip
#   inflating: xpresso_predict.py
#    creating: input_fasta/
#    creating: pretrained_models/
#   inflating: input_fasta/human_promoters.fa.gz
#   inflating: input_fasta/mouse_promoters.fa.gz
#   inflating: input_fasta/testinput.fa.gz
#   inflating: pretrained_models/GM12878_trainepoch.06-0.5062.h5
#   inflating: pretrained_models/K562_trainepoch.11-0.4917.h5
#   inflating: pretrained_models/humanMedian_trainepoch.11-0.426.h5
#   inflating: pretrained_models/mESC_trainepoch.10-0.3867.h5
#   inflating: pretrained_models/mouseMedian_trainepoch.05-0.278.h5
# Requirement already satisfied: biopython in /usr/local/lib/python3.6/dist-packages (1.76)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from biopython) (1.18.2)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.10.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.2)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.12.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.38.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)
# TF version 1.15.0
# Keras version 2.2.4-tf
# Found GPU at: /device:GPU:0

# %% [markdown]
# # Train Xpresso model for human data

# %%
# Results presented in the paper are the best of 10 independent trials, choosing the one that minimizes
# validation mean squared error loss.
# These results are not exactly those shown in paper due to variability in performance

global X_trainhalflife, X_trainpromoter, y_train, X_validhalflife, X_validpromoter, y_valid, X_testhalflife, X_testpromoter, y_test, geneName_test, params, best_file

def main(datadir):
    global X_trainhalflife, X_trainpromoter, y_train, X_validhalflife, X_validpromoter, y_valid, X_testhalflife, X_testpromoter, y_test, geneName_test, params
    params['datadir'] = datadir
    trainfile = h5py.File(os.path.join(datadir, 'train.h5'), 'r')
    X_trainhalflife, X_trainpromoter, y_train, geneName_train = trainfile['data'], trainfile['promoter'], trainfile['label'], trainfile['geneName']
    validfile = h5py.File(os.path.join(datadir, 'valid.h5'), 'r')
    X_validhalflife, X_validpromoter, y_valid, geneName_valid = validfile['data'], validfile['promoter'], validfile['label'], validfile['geneName']
    testfile = h5py.File(os.path.join(datadir, 'test.h5'), 'r')
    X_testhalflife, X_testpromoter, y_test, geneName_test = testfile['data'], testfile['promoter'], testfile['label'], testfile['geneName']
    #best hyperparams learned
    params = { 'datadir' : datadir, 'batchsize' : 2**7, 'leftpos' : 3000, 'rightpos' : 13500, 'activationFxn' : 'relu', 'numFiltersConv1' : 2**7, 'filterLenConv1' : 6, 'dilRate1' : 1,
                'maxPool1' : 30, 'numconvlayers' : { 'numFiltersConv2' : 2**5, 'filterLenConv2' : 9, 'dilRate2' : 1, 'maxPool2' : 10, 'numconvlayers1' : { 'numconvlayers2' : 'two' } },
                'dense1' : 2**6, 'dropout1' : 0.00099, 'numdenselayers' : { 'layers' : 'two', 'dense2' : 2, 'dropout2' : 0.01546 } }
    print("Using best identified hyperparameters from architecture search, these are:")
    print(params)
    results = objective(params)
    print("Best Validation MSE = %.3f" % results['loss'])

params = {
    'tuneMode' : 1,
    'batchsize' : 2**hp.quniform('batchsize', 5, 7, 1),
    'leftpos' : hp.quniform('leftpos', 0, 10000, 500),
    'rightpos' : hp.quniform('rightpos', 10000, 20000, 500),
    'activationFxn' : 'relu',
    'numFiltersConv1' : 2**hp.quniform('numFiltersConv1', 4, 7, 1),
    'filterLenConv1' : hp.quniform('filterLenConv1', 1, 10, 1),
    'dilRate1' : hp.quniform('dilRate1', 1, 4, 1),
    'maxPool1' : hp.quniform('maxPool1', 5, 100, 5), #5, 100, 5),
    'numconvlayers' : hp.choice('numconvlayers', [
    {
        'numconvlayers1' : 'one'
    },
    {
        'numFiltersConv2' : 2**hp.quniform('numFiltersConv2', 4, 7, 1),
        'filterLenConv2' : hp.quniform('filterLenConv2', 1, 10, 1),
        'dilRate2' : hp.quniform('dilRate2', 1, 4, 1),
        'maxPool2' : hp.quniform('maxPool2', 5, 100, 5),
        'numconvlayers1' : hp.choice('numconvlayers1', [
        {
            'numconvlayers2' : 'two'
        },
        {
            'numFiltersConv3' : 2**hp.quniform('numFiltersConv3', 4, 7, 1),
            'filterLenConv3' : hp.quniform('filterLenConv3', 1, 10, 1),
            'dilRate3' : hp.quniform('dilRate3', 1, 4, 1),
            'maxPool3' : hp.quniform('maxPool3', 5, 100, 5),
            'numconvlayers2' : hp.choice('numconvlayers2', [
            {
                'numconvlayers3' : 'three'
            },
            {
                'numFiltersConv4' : 2**hp.quniform('numFiltersConv4', 4, 7, 1),
                'filterLenConv4' : hp.quniform('filterLenConv4', 1, 10, 1),
                'dilRate4' : hp.quniform('dilRate4', 1, 4, 1),
                'maxPool4' : hp.quniform('maxPool4', 5, 100, 5),
                'numconvlayers3' : 'four'
            }])
        }])
    }]),
    'dense1' : 2**hp.quniform('dense1', 1, 8, 1),
    'dropout1' : hp.uniform('dropout1', 0, 1),
    'numdenselayers' : hp.choice('numdenselayers', [
        {
            'layers' : 'one'
        },
        {
            'layers' : 'two' ,
            'dense2' : 2**hp.quniform('dense2', 1, 8, 1),
            'dropout2' : hp.uniform('dropout2', 0, 1)
        }
    ])
}

def objective(params):
    global best_file
    leftpos = int(params['leftpos'])
    rightpos = int(params['rightpos'])
    activationFxn = params['activationFxn']
    global X_trainhalflife, y_train
    X_trainpromoterSubseq = X_trainpromoter[:,leftpos:rightpos,:]
    X_validpromoterSubseq = X_validpromoter[:,leftpos:rightpos,:]
    halflifedata = Input(shape=(X_trainhalflife.shape[1:]), name='halflife')
    input_promoter = Input(shape=X_trainpromoterSubseq.shape[1:], name='promoter')

    mse = 1
    # defined architecture with best hyperparameters
    x = Conv1D(int(params['numFiltersConv1']), int(params['filterLenConv1']), dilation_rate=int(params['dilRate1']), padding='same', kernel_initializer='glorot_normal', input_shape=X_trainpromoterSubseq.shape[1:],activation=activationFxn)(input_promoter)
    x = MaxPooling1D(int(params['maxPool1']))(x)

    if params['numconvlayers']['numconvlayers1'] != 'one':
        maxPool2 = int(params['numconvlayers']['maxPool2'])
        x = Conv1D(int(params['numconvlayers']['numFiltersConv2']), int(params['numconvlayers']['filterLenConv2']), dilation_rate=int(params['numconvlayers']['dilRate2']), padding='same', kernel_initializer='glorot_normal',activation=activationFxn)(x) #[2, 3, 4, 5, 6, 7, 8, 9, 10]
        x = MaxPooling1D(maxPool2)(x)
        if params['numconvlayers']['numconvlayers1']['numconvlayers2'] != 'two':
            maxPool3 = int(params['numconvlayers']['numconvlayers1']['maxPool3'])
            x = Conv1D(int(params['numconvlayers']['numconvlayers1']['numFiltersConv3']), int(params['numconvlayers']['numconvlayers1']['filterLenConv3']), dilation_rate=int(params['numconvlayers']['numconvlayers1']['dilRate3']), padding='same', kernel_initializer='glorot_normal',activation=activationFxn)(x) #[2, 3, 4, 5]
            x = MaxPooling1D(maxPool3)(x)
            if params['numconvlayers']['numconvlayers1']['numconvlayers2']['numconvlayers3'] != 'three':
                maxPool4 = int(params['numconvlayers']['numconvlayers1']['numconvlayers2']['maxPool4'])
                x = Conv1D(int(params['numconvlayers']['numconvlayers1']['numconvlayers2']['numFiltersConv4']), int(params['numconvlayers']['numconvlayers1']['numconvlayers2']['filterLenConv4']), dilation_rate=int(params['numconvlayers']['numconvlayers1']['numconvlayers2']['dilRate4']), padding='same', kernel_initializer='glorot_normal',activation=activationFxn)(x) #[2, 3, 4, 5]
                x = MaxPooling1D(maxPool4)(x)

    x = Flatten()(x)
    x = Concatenate()([x, halflifedata])
    x = Dense(int(params['dense1']))(x)
    x = Activation(activationFxn)(x)
    x = Dropout(params['dropout1'])(x)
    if params['numdenselayers']['layers'] == 'two':
        x = Dense(int(params['numdenselayers']['dense2']))(x)
        x = Activation(activationFxn)(x)
        x = Dropout(params['numdenselayers']['dropout2'])(x)
    main_output = Dense(1)(x)
    model = Model(inputs=[input_promoter, halflifedata], outputs=[main_output])
    model.compile(SGD(lr=0.0005, momentum=0.9),'mean_squared_error', metrics=['mean_squared_error'])
    # model.compile(Adam(lr=0.0005, beta_1=0.9, beta_2=0.90, epsilon=1e-08, decay=0.0),'mean_squared_error', metrics=['mean_squared_error'])

    print(model.summary())
    modelfile = os.path.join(params['datadir'], 'plotted_model.png')
    plot_model(model, show_shapes=True, show_layer_names=True, to_file=modelfile)

    #train model on training set and eval on 1K validation set
    check_cb = ModelCheckpoint(os.path.join(params['datadir'], 'bestparams.h5'), monitor='val_loss', verbose=1, save_best_only=True, mode='min')
    earlystop_cb = EarlyStopping(monitor='val_loss', patience=7, verbose=1, mode='min')
    result = model.fit([X_trainpromoterSubseq, X_trainhalflife], y_train, batch_size=int(params['batchsize']), shuffle="batch", epochs=100,
        validation_data=[[X_validpromoterSubseq, X_validhalflife], y_valid], callbacks=[earlystop_cb, check_cb])
    mse_history = result.history['val_mean_squared_error']
    mse = min(mse_history)
    
    #evaluate performance on test set using best learned model
    best_file = os.path.join(params['datadir'], 'bestparams.h5')
    model = load_model(best_file)
    print('Loaded results from:', best_file)
    X_testpromoterSubseq = X_testpromoter[:,leftpos:rightpos,:]
    predictions_test = model.predict([X_testpromoterSubseq, X_testhalflife], batch_size=64).flatten()
    slope, intercept, r_value, p_value, std_err = stats.linregress(predictions_test, y_test)
    print('Test R^2 = %.3f' % r_value**2)
    df = pd.DataFrame(np.column_stack((geneName_test, predictions_test, y_test)), columns=['Gene','Pred','Actual'])
    
    print('Rows & Cols:', df.shape)
    df.to_csv(os.path.join(params['datadir'], 'predictions.txt'), index=False, header=True, sep='\t')

    return {'loss': mse, 'status': STATUS_OK }

datadir="pM10Kb_1KTest"
main(datadir=datadir)

#Matches FigS2A
Image(retina=True, filename=os.path.join(datadir, 'plotted_model.png'))
# Out:
# Using best identified hyperparameters from architecture search, these are:
# {'datadir': 'pM10Kb_1KTest', 'batchsize': 128, 'leftpos': 3000, 'rightpos': 13500, 'activationFxn': 'relu', 'numFiltersConv1': 128, 'filterLenConv1': 6, 'dilRate1': 1, 'maxPool1': 30, 'numconvlayers': {'numFiltersConv2': 32, 'filterLenConv2': 9, 'dilRate2': 1, 'maxPool2': 10, 'numconvlayers1': {'numconvlayers2': 'two'}}, 'dense1': 64, 'dropout1': 0.00099, 'numdenselayers': {'layers': 'two', 'dense2': 2, 'dropout2': 0.01546}}
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# promoter (InputLayer)           (None, 10500, 4)     0
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 10500, 128)   3200        promoter[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 350, 128)     0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 350, 32)      36896       max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 35, 32)       0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 1120)         0           max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# halflife (InputLayer)           (None, 8)            0
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1128)         0           flatten_2[0][0]
#                                                                  halflife[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           72256       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 64)           0           activation_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 2)            130         dropout_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 2)            0           dense_5[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 2)            0           activation_4[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 1)            3           dropout_4[0][0]
# ==================================================================================================
# Total params: 112,485
# Trainable params: 112,485
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 16377 samples, validate on 1000 samples
# Epoch 1/100
# 16377/16377 [==============================] - 29s 2ms/step - loss: 0.9375 - mean_squared_error: 0.9375 - val_loss: 0.9023 - val_mean_squared_error: 0.9023
#
# Epoch 00001: val_loss improved from inf to 0.90225, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 2/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.8496 - mean_squared_error: 0.8496 - val_loss: 0.8405 - val_mean_squared_error: 0.8405
#
# Epoch 00002: val_loss improved from 0.90225 to 0.84050, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 3/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.8184 - mean_squared_error: 0.8184 - val_loss: 0.8074 - val_mean_squared_error: 0.8074
#
# Epoch 00003: val_loss improved from 0.84050 to 0.80739, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 4/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.7816 - mean_squared_error: 0.7816 - val_loss: 0.7672 - val_mean_squared_error: 0.7672
#
# Epoch 00004: val_loss improved from 0.80739 to 0.76718, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 5/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.7330 - mean_squared_error: 0.7330 - val_loss: 0.7144 - val_mean_squared_error: 0.7144
#
# Epoch 00005: val_loss improved from 0.76718 to 0.71437, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 6/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.6887 - mean_squared_error: 0.6887 - val_loss: 0.6629 - val_mean_squared_error: 0.6629
#
# Epoch 00006: val_loss improved from 0.71437 to 0.66287, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 7/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.6438 - mean_squared_error: 0.6438 - val_loss: 0.6270 - val_mean_squared_error: 0.6270
#
# Epoch 00007: val_loss improved from 0.66287 to 0.62695, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 8/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.6210 - mean_squared_error: 0.6210 - val_loss: 0.5971 - val_mean_squared_error: 0.5971
#
# Epoch 00008: val_loss improved from 0.62695 to 0.59707, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 9/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5903 - mean_squared_error: 0.5903 - val_loss: 0.5748 - val_mean_squared_error: 0.5748
#
# Epoch 00009: val_loss improved from 0.59707 to 0.57482, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 10/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5744 - mean_squared_error: 0.5744 - val_loss: 0.5623 - val_mean_squared_error: 0.5623
#
# Epoch 00010: val_loss improved from 0.57482 to 0.56234, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 11/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5651 - mean_squared_error: 0.5651 - val_loss: 0.5893 - val_mean_squared_error: 0.5893
#
# Epoch 00011: val_loss did not improve from 0.56234
# Epoch 12/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5535 - mean_squared_error: 0.5535 - val_loss: 0.5310 - val_mean_squared_error: 0.5310
#
# Epoch 00012: val_loss improved from 0.56234 to 0.53097, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 13/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5391 - mean_squared_error: 0.5391 - val_loss: 0.5390 - val_mean_squared_error: 0.5390
#
# Epoch 00013: val_loss did not improve from 0.53097
# Epoch 14/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5301 - mean_squared_error: 0.5301 - val_loss: 0.5149 - val_mean_squared_error: 0.5149
#
# Epoch 00014: val_loss improved from 0.53097 to 0.51487, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 15/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5175 - mean_squared_error: 0.5175 - val_loss: 0.5036 - val_mean_squared_error: 0.5036
#
# Epoch 00015: val_loss improved from 0.51487 to 0.50359, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 16/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5107 - mean_squared_error: 0.5107 - val_loss: 0.5408 - val_mean_squared_error: 0.5408
#
# Epoch 00016: val_loss did not improve from 0.50359
# Epoch 17/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.5037 - mean_squared_error: 0.5037 - val_loss: 0.5031 - val_mean_squared_error: 0.5031
#
# Epoch 00017: val_loss improved from 0.50359 to 0.50311, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 18/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4996 - mean_squared_error: 0.4996 - val_loss: 0.4974 - val_mean_squared_error: 0.4974
#
# Epoch 00018: val_loss improved from 0.50311 to 0.49741, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 19/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4854 - mean_squared_error: 0.4854 - val_loss: 0.4845 - val_mean_squared_error: 0.4845
#
# Epoch 00019: val_loss improved from 0.49741 to 0.48447, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 20/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4789 - mean_squared_error: 0.4789 - val_loss: 0.4761 - val_mean_squared_error: 0.4761
#
# Epoch 00020: val_loss improved from 0.48447 to 0.47607, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 21/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4842 - mean_squared_error: 0.4842 - val_loss: 0.4707 - val_mean_squared_error: 0.4707
#
# Epoch 00021: val_loss improved from 0.47607 to 0.47071, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 22/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4669 - mean_squared_error: 0.4669 - val_loss: 0.4642 - val_mean_squared_error: 0.4642
#
# Epoch 00022: val_loss improved from 0.47071 to 0.46416, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 23/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4610 - mean_squared_error: 0.4610 - val_loss: 0.4824 - val_mean_squared_error: 0.4824
#
# Epoch 00023: val_loss did not improve from 0.46416
# Epoch 24/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4621 - mean_squared_error: 0.4621 - val_loss: 0.5315 - val_mean_squared_error: 0.5315
#
# Epoch 00024: val_loss did not improve from 0.46416
# Epoch 25/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4554 - mean_squared_error: 0.4554 - val_loss: 0.4569 - val_mean_squared_error: 0.4569
#
# Epoch 00025: val_loss improved from 0.46416 to 0.45687, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 26/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4414 - mean_squared_error: 0.4414 - val_loss: 0.4513 - val_mean_squared_error: 0.4513
#
# Epoch 00026: val_loss improved from 0.45687 to 0.45125, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 27/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4365 - mean_squared_error: 0.4365 - val_loss: 0.4614 - val_mean_squared_error: 0.4614
#
# Epoch 00027: val_loss did not improve from 0.45125
# Epoch 28/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4400 - mean_squared_error: 0.4400 - val_loss: 0.5004 - val_mean_squared_error: 0.5004
#
# Epoch 00028: val_loss did not improve from 0.45125
# Epoch 29/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4255 - mean_squared_error: 0.4255 - val_loss: 0.4473 - val_mean_squared_error: 0.4473
#
# Epoch 00029: val_loss improved from 0.45125 to 0.44725, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 30/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4201 - mean_squared_error: 0.4201 - val_loss: 0.4531 - val_mean_squared_error: 0.4531
#
# Epoch 00030: val_loss did not improve from 0.44725
# Epoch 31/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4119 - mean_squared_error: 0.4119 - val_loss: 0.4731 - val_mean_squared_error: 0.4731
#
# Epoch 00031: val_loss did not improve from 0.44725
# Epoch 32/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4155 - mean_squared_error: 0.4155 - val_loss: 0.4481 - val_mean_squared_error: 0.4481
#
# Epoch 00032: val_loss did not improve from 0.44725
# Epoch 33/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4151 - mean_squared_error: 0.4151 - val_loss: 0.4453 - val_mean_squared_error: 0.4453
#
# Epoch 00033: val_loss improved from 0.44725 to 0.44534, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 34/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4139 - mean_squared_error: 0.4139 - val_loss: 0.4530 - val_mean_squared_error: 0.4530
#
# Epoch 00034: val_loss did not improve from 0.44534
# Epoch 35/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4071 - mean_squared_error: 0.4071 - val_loss: 0.4487 - val_mean_squared_error: 0.4487
#
# Epoch 00035: val_loss did not improve from 0.44534
# Epoch 36/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.4131 - mean_squared_error: 0.4131 - val_loss: 0.4416 - val_mean_squared_error: 0.4416
#
# Epoch 00036: val_loss improved from 0.44534 to 0.44158, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 37/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3980 - mean_squared_error: 0.3980 - val_loss: 0.4429 - val_mean_squared_error: 0.4429
#
# Epoch 00037: val_loss did not improve from 0.44158
# Epoch 38/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3929 - mean_squared_error: 0.3929 - val_loss: 0.4418 - val_mean_squared_error: 0.4418
#
# Epoch 00038: val_loss did not improve from 0.44158
# Epoch 39/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3913 - mean_squared_error: 0.3913 - val_loss: 0.4425 - val_mean_squared_error: 0.4425
#
# Epoch 00039: val_loss did not improve from 0.44158
# Epoch 40/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3852 - mean_squared_error: 0.3852 - val_loss: 0.4411 - val_mean_squared_error: 0.4411
#
# Epoch 00040: val_loss improved from 0.44158 to 0.44115, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 41/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3847 - mean_squared_error: 0.3847 - val_loss: 0.4483 - val_mean_squared_error: 0.4483
#
# Epoch 00041: val_loss did not improve from 0.44115
# Epoch 42/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3782 - mean_squared_error: 0.3782 - val_loss: 0.4706 - val_mean_squared_error: 0.4706
#
# Epoch 00042: val_loss did not improve from 0.44115
# Epoch 43/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3780 - mean_squared_error: 0.3780 - val_loss: 0.4403 - val_mean_squared_error: 0.4403
#
# Epoch 00043: val_loss improved from 0.44115 to 0.44035, saving model to pM10Kb_1KTest/bestparams.h5
# Epoch 44/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3744 - mean_squared_error: 0.3744 - val_loss: 0.4545 - val_mean_squared_error: 0.4545
#
# Epoch 00044: val_loss did not improve from 0.44035
# Epoch 45/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3687 - mean_squared_error: 0.3687 - val_loss: 0.4441 - val_mean_squared_error: 0.4441
#
# Epoch 00045: val_loss did not improve from 0.44035
# Epoch 46/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3681 - mean_squared_error: 0.3681 - val_loss: 0.4532 - val_mean_squared_error: 0.4532
#
# Epoch 00046: val_loss did not improve from 0.44035
# Epoch 47/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3749 - mean_squared_error: 0.3749 - val_loss: 0.4613 - val_mean_squared_error: 0.4613
#
# Epoch 00047: val_loss did not improve from 0.44035
# Epoch 48/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3564 - mean_squared_error: 0.3564 - val_loss: 0.4510 - val_mean_squared_error: 0.4510
#
# Epoch 00048: val_loss did not improve from 0.44035
# Epoch 49/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3620 - mean_squared_error: 0.3620 - val_loss: 0.4670 - val_mean_squared_error: 0.4670
#
# Epoch 00049: val_loss did not improve from 0.44035
# Epoch 50/100
# 16377/16377 [==============================] - 28s 2ms/step - loss: 0.3568 - mean_squared_error: 0.3568 - val_loss: 0.4559 - val_mean_squared_error: 0.4559
#
# Epoch 00050: val_loss did not improve from 0.44035
# Epoch 00050: early stopping
# Loaded results from: pM10Kb_1KTest/bestparams.h5
# Test R^2 = 0.581
# Rows & Cols: (1000, 3)
# Best Validation MSE = 0.440

# %% [markdown]
# # Generate predictions on a tiled genomic locus or other group of DNA sequences

# %%
def one_hot(seq):
    num_seqs = len(seq)
    seq_len = len(seq[0])
    seqindex = {'A':0, 'C':1, 'G':2, 'T':3, 'a':0, 'c':1, 'g':2, 't':3}
    seq_vec = np.zeros((num_seqs,seq_len,4), dtype='bool')
    for i in range(num_seqs):
        thisseq = seq[i]
        for j in range(seq_len):
            try:
                seq_vec[i,j,seqindex[thisseq[j]]] = 1
            except:
                pass
    return seq_vec

def generate_predictions(model_file, input_file, output_file):
    model = load_model(best_file) #or use one of several pre-trained models
    encoding = guess_type(input_file)[1]  # uses file extension to guess zipped or unzipped

    if encoding is None:
        _open = open
    elif encoding == 'gzip':
        _open = partial(gzip.open, mode='rt')
    else:
        raise ValueError('Unknown file encoding: "{}"'.format(encoding))

    i, bs, names, predictions, sequences = 0, 32, [], [], []
    hlfeatures=8
    halflifedata = np.zeros((bs,hlfeatures), dtype='float32')

    with _open(input_file) as f:
        for fasta in SeqIO.parse(f, 'fasta'):
            name, sequence = fasta.id, str(fasta.seq)
            sequences.append(sequence)
            names.append(name)
            i += 1
            if (len(sequence) != 10500):
                sys.exit( "Error in sequence %s, length is not equal to the required 10,500 nts. Please fix or pad with Ns if necessary." % name )
            if i % bs == 0:
                seq = one_hot(sequences)    
                predictions.extend( model.predict([seq, halflifedata], batch_size=bs).flatten().tolist() )
                sequences = []

        remain = i % bs
        if remain > 0:
            halflifedata = np.zeros((remain,hlfeatures), dtype='float32')
            seq = one_hot(sequences)
            predictions.extend( model.predict([seq, halflifedata], batch_size=remain).flatten().tolist() )

        df = pd.DataFrame(np.column_stack((names, predictions)), columns=['ID','SCORE'])
        print(df[1:10]) #print first 10 entries
        df.to_csv(output_file, index=False, header=True, sep='\t')

generate_predictions(model_file="pM10Kb_1KTest/bestparams.h5", 
                     input_file="input_fasta/testinput.fa.gz",
                     output_file="test_predictions.txt")
generate_predictions(model_file="pM10Kb_1KTest/bestparams.h5",
                     input_file="input_fasta/human_promoters.fa.gz",
                     output_file="human_promoter_predictions.txt")
# Out:
#                       ID                SCORE
# 1  1:109500100-109510600  -1.0128095149993896
# 2  1:109500200-109510700  -0.8385645747184753
# 3  1:109500300-109510800  -0.9124962091445923
# 4  1:109500400-109510900  -0.6896266341209412
# 5  1:109500500-109511000   -0.838095486164093
# 6  1:109500600-109511100  -0.7197431325912476
# 7  1:109500700-109511200   -0.848416805267334
# 8  1:109500800-109511300  -0.8509523272514343
# 9  1:109500900-109511400  -0.8906832337379456
#                 ID                 SCORE
# 1  ENSG00000000005   -1.3184634447097778
# 2  ENSG00000000419    1.1143244504928589
# 3  ENSG00000000457    0.4652319550514221
# 4  ENSG00000000460    0.6001622080802917
# 5  ENSG00000000938  -0.11059961467981339
# 6  ENSG00000000971   -0.9180839657783508
# 7  ENSG00000001036    0.3033240735530853
# 8  ENSG00000001084    0.6849551200866699
# 9  ENSG00000001167    0.7782650589942932

# %% [markdown]
# # Train Xpresso model for mouse data and predict promoters

# %%
main(datadir="pM10Kb_1KTest_Mouse")
generate_predictions(model_file="pM10Kb_1KTest_Mouse/bestparams.h5",
                     input_file="input_fasta/mouse_promoters.fa.gz",
                     output_file="mouse_promoter_predictions.txt")
# Out:
# Using best identified hyperparameters from architecture search, these are:
# {'datadir': 'pM10Kb_1KTest_Mouse', 'batchsize': 128, 'leftpos': 3000, 'rightpos': 13500, 'activationFxn': 'relu', 'numFiltersConv1': 128, 'filterLenConv1': 6, 'dilRate1': 1, 'maxPool1': 30, 'numconvlayers': {'numFiltersConv2': 32, 'filterLenConv2': 9, 'dilRate2': 1, 'maxPool2': 10, 'numconvlayers1': {'numconvlayers2': 'two'}}, 'dense1': 64, 'dropout1': 0.00099, 'numdenselayers': {'layers': 'two', 'dense2': 2, 'dropout2': 0.01546}}
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# promoter (InputLayer)           (None, 10500, 4)     0
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 10500, 128)   3200        promoter[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 350, 128)     0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 350, 32)      36896       max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_8 (MaxPooling1D)  (None, 35, 32)       0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 1120)         0           max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# halflife (InputLayer)           (None, 8)            0
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 1128)         0           flatten_4[0][0]
#                                                                  halflife[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 64)           72256       concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 64)           0           dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 64)           0           activation_7[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 2)            130         dropout_7[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 2)            0           dense_11[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 2)            0           activation_8[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 1)            3           dropout_8[0][0]
# ==================================================================================================
# Total params: 112,485
# Trainable params: 112,485
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Train on 19856 samples, validate on 1000 samples
# Epoch 1/100
# 19856/19856 [==============================] - 35s 2ms/step - loss: 0.9518 - mean_squared_error: 0.9518 - val_loss: 0.8972 - val_mean_squared_error: 0.8972
#
# Epoch 00001: val_loss improved from inf to 0.89716, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 2/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.8613 - mean_squared_error: 0.8613 - val_loss: 0.7868 - val_mean_squared_error: 0.7868
#
# Epoch 00002: val_loss improved from 0.89716 to 0.78676, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 3/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.7641 - mean_squared_error: 0.7641 - val_loss: 0.7091 - val_mean_squared_error: 0.7091
#
# Epoch 00003: val_loss improved from 0.78676 to 0.70910, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 4/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.6976 - mean_squared_error: 0.6976 - val_loss: 0.6319 - val_mean_squared_error: 0.6319
#
# Epoch 00004: val_loss improved from 0.70910 to 0.63195, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 5/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.6457 - mean_squared_error: 0.6457 - val_loss: 0.5858 - val_mean_squared_error: 0.5858
#
# Epoch 00005: val_loss improved from 0.63195 to 0.58581, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 6/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.5995 - mean_squared_error: 0.5995 - val_loss: 0.5430 - val_mean_squared_error: 0.5430
#
# Epoch 00006: val_loss improved from 0.58581 to 0.54300, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 7/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.5575 - mean_squared_error: 0.5575 - val_loss: 0.4918 - val_mean_squared_error: 0.4918
#
# Epoch 00007: val_loss improved from 0.54300 to 0.49181, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 8/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.5101 - mean_squared_error: 0.5101 - val_loss: 0.4358 - val_mean_squared_error: 0.4358
#
# Epoch 00008: val_loss improved from 0.49181 to 0.43581, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 9/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.4790 - mean_squared_error: 0.4790 - val_loss: 0.4043 - val_mean_squared_error: 0.4043
#
# Epoch 00009: val_loss improved from 0.43581 to 0.40433, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 10/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.4519 - mean_squared_error: 0.4519 - val_loss: 0.3777 - val_mean_squared_error: 0.3777
#
# Epoch 00010: val_loss improved from 0.40433 to 0.37772, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 11/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.4220 - mean_squared_error: 0.4220 - val_loss: 0.3593 - val_mean_squared_error: 0.3593
#
# Epoch 00011: val_loss improved from 0.37772 to 0.35931, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 12/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.4042 - mean_squared_error: 0.4042 - val_loss: 0.3505 - val_mean_squared_error: 0.3505
#
# Epoch 00012: val_loss improved from 0.35931 to 0.35047, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 13/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3938 - mean_squared_error: 0.3938 - val_loss: 0.3568 - val_mean_squared_error: 0.3568
#
# Epoch 00013: val_loss did not improve from 0.35047
# Epoch 14/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3814 - mean_squared_error: 0.3814 - val_loss: 0.3422 - val_mean_squared_error: 0.3422
#
# Epoch 00014: val_loss improved from 0.35047 to 0.34215, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 15/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3702 - mean_squared_error: 0.3702 - val_loss: 0.3206 - val_mean_squared_error: 0.3206
#
# Epoch 00015: val_loss improved from 0.34215 to 0.32059, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 16/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3619 - mean_squared_error: 0.3619 - val_loss: 0.3084 - val_mean_squared_error: 0.3084
#
# Epoch 00016: val_loss improved from 0.32059 to 0.30835, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 17/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3561 - mean_squared_error: 0.3561 - val_loss: 0.3112 - val_mean_squared_error: 0.3112
#
# Epoch 00017: val_loss did not improve from 0.30835
# Epoch 18/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3549 - mean_squared_error: 0.3549 - val_loss: 0.3179 - val_mean_squared_error: 0.3179
#
# Epoch 00018: val_loss did not improve from 0.30835
# Epoch 19/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3420 - mean_squared_error: 0.3420 - val_loss: 0.3057 - val_mean_squared_error: 0.3057
#
# Epoch 00019: val_loss improved from 0.30835 to 0.30573, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 20/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3368 - mean_squared_error: 0.3368 - val_loss: 0.3079 - val_mean_squared_error: 0.3079
#
# Epoch 00020: val_loss did not improve from 0.30573
# Epoch 21/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3354 - mean_squared_error: 0.3354 - val_loss: 0.2906 - val_mean_squared_error: 0.2906
#
# Epoch 00021: val_loss improved from 0.30573 to 0.29064, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 22/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3281 - mean_squared_error: 0.3281 - val_loss: 0.2946 - val_mean_squared_error: 0.2946
#
# Epoch 00022: val_loss did not improve from 0.29064
# Epoch 23/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3189 - mean_squared_error: 0.3189 - val_loss: 0.2883 - val_mean_squared_error: 0.2883
#
# Epoch 00023: val_loss improved from 0.29064 to 0.28826, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 24/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3219 - mean_squared_error: 0.3219 - val_loss: 0.2915 - val_mean_squared_error: 0.2915
#
# Epoch 00024: val_loss did not improve from 0.28826
# Epoch 25/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3198 - mean_squared_error: 0.3198 - val_loss: 0.2843 - val_mean_squared_error: 0.2843
#
# Epoch 00025: val_loss improved from 0.28826 to 0.28426, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 26/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3165 - mean_squared_error: 0.3165 - val_loss: 0.2892 - val_mean_squared_error: 0.2892
#
# Epoch 00026: val_loss did not improve from 0.28426
# Epoch 27/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3135 - mean_squared_error: 0.3135 - val_loss: 0.2845 - val_mean_squared_error: 0.2845
#
# Epoch 00027: val_loss did not improve from 0.28426
# Epoch 28/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3124 - mean_squared_error: 0.3124 - val_loss: 0.2848 - val_mean_squared_error: 0.2848
#
# Epoch 00028: val_loss did not improve from 0.28426
# Epoch 29/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3097 - mean_squared_error: 0.3097 - val_loss: 0.2943 - val_mean_squared_error: 0.2943
#
# Epoch 00029: val_loss did not improve from 0.28426
# Epoch 30/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3039 - mean_squared_error: 0.3039 - val_loss: 0.2849 - val_mean_squared_error: 0.2849
#
# Epoch 00030: val_loss did not improve from 0.28426
# Epoch 31/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3040 - mean_squared_error: 0.3040 - val_loss: 0.2848 - val_mean_squared_error: 0.2848
#
# Epoch 00031: val_loss did not improve from 0.28426
# Epoch 32/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3000 - mean_squared_error: 0.3000 - val_loss: 0.2790 - val_mean_squared_error: 0.2790
#
# Epoch 00032: val_loss improved from 0.28426 to 0.27905, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 33/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.3001 - mean_squared_error: 0.3001 - val_loss: 0.2815 - val_mean_squared_error: 0.2815
#
# Epoch 00033: val_loss did not improve from 0.27905
# Epoch 34/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2976 - mean_squared_error: 0.2976 - val_loss: 0.2939 - val_mean_squared_error: 0.2939
#
# Epoch 00034: val_loss did not improve from 0.27905
# Epoch 35/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2909 - mean_squared_error: 0.2909 - val_loss: 0.2822 - val_mean_squared_error: 0.2822
#
# Epoch 00035: val_loss did not improve from 0.27905
# Epoch 36/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2947 - mean_squared_error: 0.2947 - val_loss: 0.2891 - val_mean_squared_error: 0.2891
#
# Epoch 00036: val_loss did not improve from 0.27905
# Epoch 37/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2873 - mean_squared_error: 0.2873 - val_loss: 0.2786 - val_mean_squared_error: 0.2786
#
# Epoch 00037: val_loss improved from 0.27905 to 0.27864, saving model to pM10Kb_1KTest_Mouse/bestparams.h5
# Epoch 38/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2900 - mean_squared_error: 0.2900 - val_loss: 0.2806 - val_mean_squared_error: 0.2806
#
# Epoch 00038: val_loss did not improve from 0.27864
# Epoch 39/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2849 - mean_squared_error: 0.2849 - val_loss: 0.2848 - val_mean_squared_error: 0.2848
#
# Epoch 00039: val_loss did not improve from 0.27864
# Epoch 40/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2769 - mean_squared_error: 0.2769 - val_loss: 0.2804 - val_mean_squared_error: 0.2804
#
# Epoch 00040: val_loss did not improve from 0.27864
# Epoch 41/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2838 - mean_squared_error: 0.2838 - val_loss: 0.2818 - val_mean_squared_error: 0.2818
#
# Epoch 00041: val_loss did not improve from 0.27864
# Epoch 42/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2736 - mean_squared_error: 0.2736 - val_loss: 0.2874 - val_mean_squared_error: 0.2874
#
# Epoch 00042: val_loss did not improve from 0.27864
# Epoch 43/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2741 - mean_squared_error: 0.2741 - val_loss: 0.2832 - val_mean_squared_error: 0.2832
#
# Epoch 00043: val_loss did not improve from 0.27864
# Epoch 44/100
# 19856/19856 [==============================] - 34s 2ms/step - loss: 0.2731 - mean_squared_error: 0.2731 - val_loss: 0.2854 - val_mean_squared_error: 0.2854
#
# Epoch 00044: val_loss did not improve from 0.27864
# Epoch 00044: early stopping
# Loaded results from: pM10Kb_1KTest_Mouse/bestparams.h5
# Test R^2 = 0.710
# Rows & Cols: (1000, 3)
# Best Validation MSE = 0.279
#                    ID                 SCORE
# 1  ENSMUSG00000000003   -0.9580053091049194
# 2  ENSMUSG00000000028    0.5492274761199951
# 3  ENSMUSG00000000037  -0.09932154417037964
# 4  ENSMUSG00000000049    -0.881689190864563
# 5  ENSMUSG00000000056    0.7828924655914307
# 6  ENSMUSG00000000058   -0.4674728810787201
# 7  ENSMUSG00000000078    1.0640679597854614
# 8  ENSMUSG00000000085    0.8793935775756836
# 9  ENSMUSG00000000088    1.2158082723617554
